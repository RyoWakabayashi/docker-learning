# %% [markdown]
# # Docker Learning Jupyter\n\nこの notebook は Docker コンテナ上の JupyterLab で開かれます。\n\n- コンテナを再作成しても `work` フォルダ配下の notebook はホスト側に残ります\n- まずは下のコードセルを実行してみてください

# %%
message = "Hello from Jupyter running in Docker!"\nprint(message)

# %%
numbers = [1, 2, 3, 4, 5]\nsum(numbers), len(numbers)
